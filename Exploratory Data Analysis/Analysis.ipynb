# %% [markdown]
# # Analysis of Assumptions - Uber Speeds

# %%
import numpy as np; np.random.seed(42)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5

# %%
df = pd.read_csv("2019-Jan-Daily-Aggregated.csv", index_col = 0)

# %%
df["date"] = df['year'].astype(str)+'-'+df['month'].astype(str)+'-'+df['day'].astype(str)

# %%
df["date"]= pd.to_datetime(df["date"])

# %%
week_days = {0:"Monday", 1:"Tuesday", 2:"Wednesday", 3:"Thursday", 4:"Friday", 5:"Saturday", 6:"Sunday"}

# %%
df["day_of_week"] = df['date'].dt.dayofweek

# %%
df
# Out:
#     year  month  day  speed_mph_mean  speed_mph_stddev       date  day_of_week
# 1   2019      1    1       33.352492          5.693520 2019-01-01            1
# 2   2019      1    2       32.470983          6.094921 2019-01-02            2
# 3   2019      1    3       30.309660          6.102640 2019-01-03            3
# 4   2019      1    4       30.567950          5.996863 2019-01-04            4
# 5   2019      1    5       31.478367          5.680409 2019-01-05            5
# 6   2019      1    6       32.935633          5.693706 2019-01-06            6
# 7   2019      1    7       31.106664          6.191277 2019-01-07            0
# 8   2019      1    8       29.149109          6.209379 2019-01-08            1
# 9   2019      1    9       28.806124          6.200961 2019-01-09            2
# 10  2019      1   10       29.455230          6.154581 2019-01-10            3
# 11  2019      1   11       29.383279          5.986875 2019-01-11            4
# 12  2019      1   12       30.289458          5.621145 2019-01-12            5
# 13  2019      1   13       32.145197          5.714843 2019-01-13            6
# 14  2019      1   14       30.125704          6.170882 2019-01-14            0
# 15  2019      1   15       29.516259          6.163622 2019-01-15            1
# 16  2019      1   16       29.448958          6.173272 2019-01-16            2
# 17  2019      1   17       28.762671          6.079797 2019-01-17            3
# 18  2019      1   18       28.731763          6.006238 2019-01-18            4
# 19  2019      1   19       30.424327          5.660666 2019-01-19            5
# 20  2019      1   20       32.118430          5.658535 2019-01-20            6
# 21  2019      1   21       31.985812          5.942907 2019-01-21            0
# 22  2019      1   22       28.946453          6.150479 2019-01-22            1
# 23  2019      1   23       29.411125          6.142239 2019-01-23            2
# 24  2019      1   24       29.354424          6.136597 2019-01-24            3
# 25  2019      1   25       28.688990          6.047576 2019-01-25            4
# 26  2019      1   26       30.238673          5.692315 2019-01-26            5
# 27  2019      1   27       32.383898          5.700626 2019-01-27            6
# 28  2019      1   28       30.356045          6.191582 2019-01-28            0
# 29  2019      1   29       29.364195          6.251267 2019-01-29            1
# 30  2019      1   30       29.648290          6.172871 2019-01-30            2
# 31  2019      1   31       29.270492          6.163334 2019-01-31            3

# %%
std_dev = {}
for day in range(7):
    std_dev[week_days[day]] = (df[df["day_of_week"] == day]["speed_mph_mean"].std()) 
    
std_dev
# Out:
# {'Monday': 0.8400302145066592,
#  'Tuesday': 1.8499899558915731,
#  'Wednesday': 1.4401400065659806,
#  'Thursday': 0.5592226400623584,
#  'Friday': 0.876254243383524,
#  'Saturday': 0.585703205863367,
#  'Sunday': 0.3791642878625216}

# %%
plt.bar(range(len(std_dev)), list(std_dev.values()), align='center')
plt.xticks(range(len(std_dev)), list(std_dev.keys()))
plt.show()

# %%
dayofweek_dic = {}
for day in range(7):
    dayofweek_dic[week_days[day]] = df[df["day_of_week"] == day]["speed_mph_mean"].tolist()

# %%
dayofweek_dic
# Out:
# {'Monday': [31.106663745956997,
#   30.1257041594114,
#   31.985811680743605,
#   30.3560446501166],
#  'Tuesday': [33.3524922190605,
#   29.1491090636302,
#   29.516259351592804,
#   28.9464527721772,
#   29.3641945270432],
#  'Wednesday': [32.4709829468889,
#   28.8061240674677,
#   29.448958440555,
#   29.411125366013398,
#   29.648289798090897],
#  'Thursday': [30.309660125803298,
#   29.455229611607198,
#   28.7626709687426,
#   29.3544240533038,
#   29.2704918764756],
#  'Friday': [30.5679496367312,
#   29.3832786264399,
#   28.731762769565897,
#   28.6889896292169],
#  'Saturday': [31.4783667546736,
#   30.2894584075379,
#   30.424327245380503,
#   30.238673090093698],
#  'Sunday': [32.9356325814184,
#   32.145196934218,
#   32.1184303729462,
#   32.383898342347194]}

# %%
# or backwards compatable    
labels, data = dayofweek_dic.keys(), dayofweek_dic.values()

plt.boxplot(data)
plt.xticks(range(1, len(labels) + 1), labels)
plt.show()
